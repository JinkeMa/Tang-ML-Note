# %% [markdown]
# 1、线性回归原理推导

# %%
import torch
import torch.nn as nn
import numpy as np

class LinearRegressionModel(nn.Module):
    def __init__(self, inputdim, outputdim):
        super(LinearRegressionModel,self).__init__()
        self.linear = nn.Linear(inputdim, outputdim)

    def forward(self, x):
        output = self.linear(x)
        return output

# %%
x_values = [x for x in range(11)]
x_train = np.array(x_values, dtype = np.float32)
x_train = x_train.reshape(-1,1)
y_values = [y*2 for y in x_values]
y_train = np.array(y_values, dtype = np.float32)
y_train = y_train.reshape(-1,1)

# %%
inputdim = 1
outputdim = 1
epochs = 1000
model = LinearRegressionModel(inputdim, outputdim)
learning_rate = 0.01
optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)
criterion = nn.MSELoss()

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)

# %%
for epoch in range(epochs):
    epoch += 1

    inputs = torch.from_numpy(x_train).to(device)
    labels = torch.from_numpy(y_train).to(device)

    optimizer.zero_grad()

    outputs = model(inputs)

    loss = criterion(outputs, labels)

    loss.backward()

    optimizer.step()

    if epoch % 50 == 0:
        print("epoch {}, loss {}",epoch, loss)

# %%
import numpy as np
import torch 
import torch.nn as nn

class mLinear(nn.Module):
    def __init__(self,idim,odim):
        super(mLinear,self).__init__()
        self.linear = nn.Linear(inputdim,outputdim)

    def forward(self,x):
        o = self.linear(x)
        return o

x_v = [x for x in range (100)]
x_train = np.array(x_v, dtype = np.float32)
x_train = x_train.reshape(-1, 1)
y_v = [y for y in x_v]
y_train = np.array(y_v, dtype = np.float32)
y_train = y_train.reshape(-1, 1)

idim = 1
odim = 1
learning_rate = 0.01
epochs = 1000

model = mLinear(idim, odim)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)

optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)
criterion = nn.MSELoss()

for epoch in range(epochs):
    epoch += 1

    ips = torch.from_numpy(x_train).to(device)
    lbs = torch.from_numpy(y_train).to(device)

    optimizer.zero_grad()

    ops = model(ips)

    loss = criterion(ops, lbs)

    loss.backward()

    optimizer.step()

    if epoch % 50 == 0:
        print("epoch {}, loss {}",epoch, loss)
